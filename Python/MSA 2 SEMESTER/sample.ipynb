# %%
import pandas as pd
import math
from IPython.display import display
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram
import numpy as np

# ==========================================
# ДАНІ ВАРІАНТА 4
# ==========================================
data_var4 = {
    'Країна': ['k1_Нова Зеландія', 'k2_Норвегія', 'k3_ОАЕ', 'k4_ПАР', 'k5_Південна Корея',
               'k6_Північна Корея', 'k7_Польща', 'k8_Португалія', 'k9_Росія', 'k10_Саудівська Аравія'],
    'Ознака_1': [3524, 4300, 2800, 43900, 45000, 23100, 38600, 10500, 149200, 18000],
    'Ознака_6': [14381, 17755, 14193, 3128, 6627, 1000, 4429, 9000, 6680, 6651],
    'Ознака_8': [84, 75, 81, 49, 72, 60, 62, 34, 74, 77],
    'Ознака_9': [99, 99, 68, 76, 96, 99, 99, 85, 99, 62]
}
df = pd.DataFrame(data_var4).set_index('Країна')

print("1. Вихідні дані:")
display(df)

# --- РУЧНА НОРМАЛІЗАЦІЯ ---
df_scaled = pd.DataFrame(index=df.index, columns=df.columns)
for col in df.columns:
    col_mean = sum(df[col]) / len(df[col])
    # Розрахунок стандартного відхилення
    variance = sum((x - col_mean) ** 2 for x in df[col]) / len(df[col])
    col_std = math.sqrt(variance)
    # Нормалізація значень
    df_scaled[col] = [(x - col_mean) / col_std for x in df[col]]

print("\n2. Нормалізовані дані (вручну):")
display(df_scaled.round(4))

# --- РУЧНИЙ РОЗРАХУНОК МАТРИЦІ ЕВКЛІДОВИХ ВІДСТАНЕЙ ---
n = len(df_scaled)
dist_matrix = pd.DataFrame(0.0, index=df.index, columns=df.index)

for i in range(n):
    for j in range(n):
        if i != j:
            # Сума квадратів різниць по кожній ознаці
            sum_sq = sum((df_scaled.iloc[i, k] - df_scaled.iloc[j, k])**2 for k in range(len(df_scaled.columns)))
            dist_matrix.iloc[i, j] = math.sqrt(sum_sq)

print("\n3. Початкова матриця відстаней D0 (вручну):")
initial_dist_matrix = dist_matrix.copy() # Збережемо для дивізимного методу
display(dist_matrix.round(3))
# Out:
# 1. Вихідні дані:
#                        Ознака_1  Ознака_6  Ознака_8  Ознака_9
# Країна
# k1_Нова Зеландія           3524     14381        84        99
# k2_Норвегія                4300     17755        75        99
# k3_ОАЕ                     2800     14193        81        68
# k4_ПАР                    43900      3128        49        76
# k5_Південна Корея         45000      6627        72        96
# k6_Північна Корея         23100      1000        60        99
# k7_Польща                 38600      4429        62        99
# k8_Португалія             10500      9000        34        85
# k9_Росія                 149200      6680        74        99
# k10_Саудівська Аравія     18000      6651        77        62
# 2. Нормалізовані дані (вручну):
#                        Ознака_1  Ознака_6  Ознака_8  Ознака_9
# Країна
# k1_Нова Зеландія        -0.7318    1.1656    1.1571    0.7840
# k2_Норвегія             -0.7131    1.8214    0.5516    0.7840
# k3_ОАЕ                  -0.7492    1.1290    0.9553   -1.4664
# k4_ПАР                   0.2411   -1.0217   -1.1975   -0.8856
# k5_Південна Корея        0.2677   -0.3416    0.3498    0.5662
# k6_Північна Корея       -0.2601   -1.4353   -0.4575    0.7840
# k7_Польща                0.1134   -0.7688   -0.3229    0.7840
# k8_Португалія           -0.5637    0.1197   -2.2066   -0.2323
# k9_Росія                 2.7785   -0.3313    0.4844    0.7840
# k10_Саудівська Аравія   -0.3829   -0.3369    0.6862   -1.9019
# 3. Початкова матриця відстаней D0 (вручну):
# Країна                 k1_Нова Зеландія  k2_Норвегія  k3_ОАЕ  k4_ПАР  \
# Країна
# k1_Нова Зеландія                  0.000        0.893   2.260   3.750
# k2_Норвегія                       0.893        0.000   2.389   3.852
# k3_ОАЕ                            2.260        2.389   0.000   3.252
# k4_ПАР                            3.750        3.852   3.252   0.000
# k5_Південна Корея                 1.992        2.393   2.774   2.228
# k6_Північна Корея                 3.097        3.439   3.725   1.938
# k7_Польща                         2.578        2.856   3.323   1.906
# k8_Португалія                     3.670        3.400   3.546   1.843
# k9_Росія                          3.875        4.102   4.457   3.540
# k10_Саудівська Аравія             3.133        3.464   1.595   2.332
#
# Країна                 k5_Південна Корея  k6_Північна Корея  k7_Польща  \
# Країна
# k1_Нова Зеландія                   1.992              3.097      2.578
# k2_Норвегія                        2.393              3.439      2.856
# k3_ОАЕ                             2.774              3.725      3.323
# k4_ПАР                             2.228              1.938      1.906
# k5_Південна Корея                  0.000              1.474      0.840
# k6_Північна Корея                  1.474              0.000      0.776
# k7_Польща                          0.840              0.776      0.000
# k8_Португалія                      2.842              2.570      2.414
# k9_Росія                           2.524              3.367      2.819
# k10_Саудівська Аравія              2.575              3.122      2.944
#
# Країна                 k8_Португалія  k9_Росія  k10_Саудівська Аравія
# Країна
# k1_Нова Зеландія               3.670     3.875                  3.133
# k2_Норвегія                    3.400     4.102                  3.464
# k3_ОАЕ                         3.546     4.457                  1.595
# k4_ПАР                         1.843     3.540                  2.332
# k5_Південна Корея              2.842     2.524                  2.575
# k6_Північна Корея              2.570     3.367                  3.122
# k7_Польща                      2.414     2.819                  2.944
# k8_Португалія                  0.000     4.433                  3.376
# k9_Росія                       4.433     0.000                  4.153
# k10_Саудівська Аравія          3.376     4.153                  0.000

# %%
print("=== АГЛОМЕРАТИВНИЙ МЕТОД (КРОК ЗА КРОКОМ) ===")

current_dist = initial_dist_matrix.copy()
n_samples = len(current_dist)

# Для побудови дендрограми нам потрібно вручну зібрати матрицю Z (linkage matrix)
# Формат кожного рядка Z: [id_кластера_1, id_кластера_2, відстань, кількість_елементів]
Z = np.zeros((n_samples - 1, 4))

# Зіставляємо кожному початковому об'єкту унікальний ID від 0 до n-1
cluster_ids = {name: i for i, name in enumerate(current_dist.index)}
# Зберігаємо кількість об'єктів у кожному кластері
cluster_sizes = {name: 1 for name in current_dist.index}

next_cluster_id = n_samples
step = 0

while len(current_dist) > 1:
    # 1. Шукаємо мінімальну відстань (не 0) у матриці
    min_dist = float('inf')
    merge_a, merge_b = None, None

    for i in range(len(current_dist.index)):
        for j in range(i + 1, len(current_dist.columns)):
            d = current_dist.iloc[i, j]
            if d < min_dist:
                min_dist = d
                merge_a = current_dist.index[i]
                merge_b = current_dist.columns[j]

    # Формуємо нову назву об'єднаного кластера для виводу
    new_cluster_name = f"({merge_a.split('_')[0]},{merge_b.split('_')[0]})"

    print(f"\nКрок {step + 1}: Мінімальна відстань d = {min_dist:.3f}. Об'єднуємо '{merge_a}' та '{merge_b}'.")

    # --- Записуємо дані у нашу ручну матрицю Z для дендрограми ---
    id_a = cluster_ids[merge_a]
    id_b = cluster_ids[merge_b]
    new_size = cluster_sizes[merge_a] + cluster_sizes[merge_b]

    Z[step, 0] = id_a
    Z[step, 1] = id_b
    Z[step, 2] = min_dist
    Z[step, 3] = new_size

    # Реєструємо новий кластер
    cluster_ids[new_cluster_name] = next_cluster_id
    cluster_sizes[new_cluster_name] = new_size
    next_cluster_id += 1
    # --------------------------------------------------------------

    # 2. Створюємо нову матрицю відстаней
    new_cols = [c for c in current_dist.columns if c not in [merge_a, merge_b]]
    new_dist = pd.DataFrame(0.0, index=new_cols + [new_cluster_name], columns=new_cols + [new_cluster_name])

    # Переносимо старі відстані для кластерів, які не змінилися
    for c1 in new_cols:
        for c2 in new_cols:
            new_dist.loc[c1, c2] = current_dist.loc[c1, c2]

    # 3. Рахуємо відстані для нового кластера (метод "найближчого сусіда")
    for c in new_cols:
        dist_to_new = min(current_dist.loc[merge_a, c], current_dist.loc[merge_b, c])
        new_dist.loc[new_cluster_name, c] = dist_to_new
        new_dist.loc[c, new_cluster_name] = dist_to_new

    current_dist = new_dist
    display(current_dist.round(3))
    step += 1

# --- ПОБУДОВА ДЕНДРОГРАМИ ---
print("\nБУДУЄМО ДЕНДРОГРАМУ НА ОСНОВІ РУЧНИХ ОБЧИСЛЕНЬ:")
plt.figure(figsize=(10, 6))
plt.title('Дендрограма (Агломеративний метод "ближнього сусіда")')

# Використовуємо dendrogram виключно для малювання нашої зібраної вручну матриці Z
dendrogram(
    Z,
    labels=[name.split('_')[1] if '_' in name else name for name in initial_dist_matrix.index],
    leaf_rotation=45,
    leaf_font_size=11,
    color_threshold=0 # Щоб усі лінії були одного кольору, як у методичці
)

plt.ylabel('Відстань об\'єднання (d)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# === АГЛОМЕРАТИВНИЙ МЕТОД (КРОК ЗА КРОКОМ) ===
#
# Крок 1: Мінімальна відстань d = 0.776. Об'єднуємо 'k6_Північна Корея' та 'k7_Польща'.
#                        k1_Нова Зеландія  k2_Норвегія  k3_ОАЕ  k4_ПАР  \
# k1_Нова Зеландія                  0.000        0.893   2.260   3.750
# k2_Норвегія                       0.893        0.000   2.389   3.852
# k3_ОАЕ                            2.260        2.389   0.000   3.252
# k4_ПАР                            3.750        3.852   3.252   0.000
# k5_Південна Корея                 1.992        2.393   2.774   2.228
# k8_Португалія                     3.670        3.400   3.546   1.843
# k9_Росія                          3.875        4.102   4.457   3.540
# k10_Саудівська Аравія             3.133        3.464   1.595   2.332
# (k6,k7)                           2.578        2.856   3.323   1.906
#
#                        k5_Південна Корея  k8_Португалія  k9_Росія  \
# k1_Нова Зеландія                   1.992          3.670     3.875
# k2_Норвегія                        2.393          3.400     4.102
# k3_ОАЕ                             2.774          3.546     4.457
# k4_ПАР                             2.228          1.843     3.540
# k5_Південна Корея                  0.000          2.842     2.524
# k8_Португалія                      2.842          0.000     4.433
# k9_Росія                           2.524          4.433     0.000
# k10_Саудівська Аравія              2.575          3.376     4.153
# (k6,k7)                            0.840          2.414     2.819
#
#                        k10_Саудівська Аравія  (k6,k7)
# k1_Нова Зеландія                       3.133    2.578
# k2_Норвегія                            3.464    2.856
# k3_ОАЕ                                 1.595    3.323
# k4_ПАР                                 2.332    1.906
# k5_Південна Корея                      2.575    0.840
# k8_Португалія                          3.376    2.414
# k9_Росія                               4.153    2.819
# k10_Саудівська Аравія                  0.000    2.944
# (k6,k7)                                2.944    0.000
# Крок 2: Мінімальна відстань d = 0.840. Об'єднуємо 'k5_Південна Корея' та '(k6,k7)'.
#                        k1_Нова Зеландія  k2_Норвегія  k3_ОАЕ  k4_ПАР  \
# k1_Нова Зеландія                  0.000        0.893   2.260   3.750
# k2_Норвегія                       0.893        0.000   2.389   3.852
# k3_ОАЕ                            2.260        2.389   0.000   3.252
# k4_ПАР                            3.750        3.852   3.252   0.000
# k8_Португалія                     3.670        3.400   3.546   1.843
# k9_Росія                          3.875        4.102   4.457   3.540
# k10_Саудівська Аравія             3.133        3.464   1.595   2.332
# (k5,(k6,k7))                      1.992        2.393   2.774   1.906
#
#                        k8_Португалія  k9_Росія  k10_Саудівська Аравія  \
# k1_Нова Зеландія               3.670     3.875                  3.133
# k2_Норвегія                    3.400     4.102                  3.464
# k3_ОАЕ                         3.546     4.457                  1.595
# k4_ПАР                         1.843     3.540                  2.332
# k8_Португалія                  0.000     4.433                  3.376
# k9_Росія                       4.433     0.000                  4.153
# k10_Саудівська Аравія          3.376     4.153                  0.000
# (k5,(k6,k7))                   2.414     2.524                  2.575
#
#                        (k5,(k6,k7))
# k1_Нова Зеландія              1.992
# k2_Норвегія                   2.393
# k3_ОАЕ                        2.774
# k4_ПАР                        1.906
# k8_Португалія                 2.414
# k9_Росія                      2.524
# k10_Саудівська Аравія         2.575
# (k5,(k6,k7))                  0.000
# Крок 3: Мінімальна відстань d = 0.893. Об'єднуємо 'k1_Нова Зеландія' та 'k2_Норвегія'.
#                        k3_ОАЕ  k4_ПАР  k8_Португалія  k9_Росія  \
# k3_ОАЕ                  0.000   3.252          3.546     4.457
# k4_ПАР                  3.252   0.000          1.843     3.540
# k8_Португалія           3.546   1.843          0.000     4.433
# k9_Росія                4.457   3.540          4.433     0.000
# k10_Саудівська Аравія   1.595   2.332          3.376     4.153
# (k5,(k6,k7))            2.774   1.906          2.414     2.524
# (k1,k2)                 2.260   3.750          3.400     3.875
#
#                        k10_Саудівська Аравія  (k5,(k6,k7))  (k1,k2)
# k3_ОАЕ                                 1.595         2.774    2.260
# k4_ПАР                                 2.332         1.906    3.750
# k8_Португалія                          3.376         2.414    3.400
# k9_Росія                               4.153         2.524    3.875
# k10_Саудівська Аравія                  0.000         2.575    3.133
# (k5,(k6,k7))                           2.575         0.000    1.992
# (k1,k2)                                3.133         1.992    0.000
# Крок 4: Мінімальна відстань d = 1.595. Об'єднуємо 'k3_ОАЕ' та 'k10_Саудівська Аравія'.
#                k4_ПАР  k8_Португалія  k9_Росія  (k5,(k6,k7))  (k1,k2)  \
# k4_ПАР          0.000          1.843     3.540         1.906    3.750
# k8_Португалія   1.843          0.000     4.433         2.414    3.400
# k9_Росія        3.540          4.433     0.000         2.524    3.875
# (k5,(k6,k7))    1.906          2.414     2.524         0.000    1.992
# (k1,k2)         3.750          3.400     3.875         1.992    0.000
# (k3,k10)        2.332          3.376     4.153         2.575    2.260
#
#                (k3,k10)
# k4_ПАР            2.332
# k8_Португалія     3.376
# k9_Росія          4.153
# (k5,(k6,k7))      2.575
# (k1,k2)           2.260
# (k3,k10)          0.000
# Крок 5: Мінімальна відстань d = 1.843. Об'єднуємо 'k4_ПАР' та 'k8_Португалія'.
#               k9_Росія  (k5,(k6,k7))  (k1,k2)  (k3,k10)  (k4,k8)
# k9_Росія         0.000         2.524    3.875     4.153    3.540
# (k5,(k6,k7))     2.524         0.000    1.992     2.575    1.906
# (k1,k2)          3.875         1.992    0.000     2.260    3.400
# (k3,k10)         4.153         2.575    2.260     0.000    2.332
# (k4,k8)          3.540         1.906    3.400     2.332    0.000
# Крок 6: Мінімальна відстань d = 1.906. Об'єднуємо '(k5,(k6,k7))' та '(k4,k8)'.
#                         k9_Росія  (k1,k2)  (k3,k10)  ((k5,(k6,k7)),(k4,k8))
# k9_Росія                   0.000    3.875     4.153                   2.524
# (k1,k2)                    3.875    0.000     2.260                   1.992
# (k3,k10)                   4.153    2.260     0.000                   2.332
# ((k5,(k6,k7)),(k4,k8))     2.524    1.992     2.332                   0.000
# Крок 7: Мінімальна відстань d = 1.992. Об'єднуємо '(k1,k2)' та '((k5,(k6,k7)),(k4,k8))'.
#                                   k9_Росія  (k3,k10)  \
# k9_Росія                             0.000     4.153
# (k3,k10)                             4.153     0.000
# ((k1,k2),((k5,(k6,k7)),(k4,k8)))     2.524     2.260
#
#                                   ((k1,k2),((k5,(k6,k7)),(k4,k8)))
# k9_Росія                                                     2.524
# (k3,k10)                                                     2.260
# ((k1,k2),((k5,(k6,k7)),(k4,k8)))                             0.000
# Крок 8: Мінімальна відстань d = 2.260. Об'єднуємо '(k3,k10)' та '((k1,k2),((k5,(k6,k7)),(k4,k8)))'.
#                                              k9_Росія  \
# k9_Росія                                        0.000
# ((k3,k10),((k1,k2),((k5,(k6,k7)),(k4,k8))))     2.524
#
#                                              ((k3,k10),((k1,k2),((k5,(k6,k7)),(k4,k8))))
# k9_Росія                                                                           2.524
# ((k3,k10),((k1,k2),((k5,(k6,k7)),(k4,k8))))                                        0.000
# Крок 9: Мінімальна відстань d = 2.524. Об'єднуємо 'k9_Росія' та '((k3,k10),((k1,k2),((k5,(k6,k7)),(k4,k8))))'.
#                                                   (k9,((k3,k10),((k1,k2),((k5,(k6,k7)),(k4,k8)))))
# (k9,((k3,k10),((k1,k2),((k5,(k6,k7)),(k4,k8)))))                                               0.0
# БУДУЄМО ДЕНДРОГРАМУ НА ОСНОВІ РУЧНИХ ОБЧИСЛЕНЬ:

# %%
print("=== ДИВІЗИМНИЙ МЕТОД (КРОК ЗА КРОКОМ) ===")

# Початковий стан: 1 кластер, що містить усі країни
clusters = [list(initial_dist_matrix.index)]
step = 1

while len(clusters) < len(initial_dist_matrix):
    max_internal_dist = -1
    cluster_to_split = None
    center1 = None
    center2 = None

    # 1. Знаходимо кластер з найбільшою внутрішньою відстанню
    for cluster in clusters:
        if len(cluster) > 1:
            # Шукаємо максимальну відстань між елементами всередині цього кластера
            for i in range(len(cluster)):
                for j in range(i + 1, len(cluster)):
                    obj1, obj2 = cluster[i], cluster[j]
                    d = initial_dist_matrix.loc[obj1, obj2]
                    if d > max_internal_dist:
                        max_internal_dist = d
                        cluster_to_split = cluster
                        center1 = obj1
                        center2 = obj2

    if cluster_to_split is None:
        break

    # 2. Формуємо два нові класи на базі знайдених центрів
    new_class_1 = [center1]
    new_class_2 = [center2]

    print(f"\nКрок {step}: Розглядаємо кластер розміром {len(cluster_to_split)} об'єктів.")
    print(f"Найбільша відстань Δd = {max_internal_dist:.3f} між '{center1}' та '{center2}'.")
    print("Вони стають центрами розбиття. Розподіляємо інші об'єкти:")

    # 3. Розподіляємо інші об'єкти кластера
    for obj in cluster_to_split:
        if obj != center1 and obj != center2:
            d_to_c1 = initial_dist_matrix.loc[obj, center1]
            d_to_c2 = initial_dist_matrix.loc[obj, center2]

            if d_to_c1 < d_to_c2:
                new_class_1.append(obj)
                print(f"  - '{obj}': до {center1} ({d_to_c1:.3f}) < до {center2} ({d_to_c2:.3f}) -> йде у Клас 1")
            else:
                new_class_2.append(obj)
                print(f"  - '{obj}': до {center1} ({d_to_c1:.3f}) > до {center2} ({d_to_c2:.3f}) -> йде у Клас 2")

    # Оновлюємо список кластерів
    clusters.remove(cluster_to_split)
    clusters.append(new_class_1)
    clusters.append(new_class_2)

    print(f"\nРЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ {step}:")
    print(f"Клас 1: {[c.split('_')[0] for c in new_class_1]}")
    print(f"Клас 2: {[c.split('_')[0] for c in new_class_2]}")
    step += 1
# Out:
# === ДИВІЗИМНИЙ МЕТОД (КРОК ЗА КРОКОМ) ===
#
# Крок 1: Розглядаємо кластер розміром 10 об'єктів.
# Найбільша відстань Δd = 4.457 між 'k3_ОАЕ' та 'k9_Росія'.
# Вони стають центрами розбиття. Розподіляємо інші об'єкти:
#   - 'k1_Нова Зеландія': до k3_ОАЕ (2.260) < до k9_Росія (3.875) -> йде у Клас 1
#   - 'k2_Норвегія': до k3_ОАЕ (2.389) < до k9_Росія (4.102) -> йде у Клас 1
#   - 'k4_ПАР': до k3_ОАЕ (3.252) < до k9_Росія (3.540) -> йде у Клас 1
#   - 'k5_Південна Корея': до k3_ОАЕ (2.774) > до k9_Росія (2.524) -> йде у Клас 2
#   - 'k6_Північна Корея': до k3_ОАЕ (3.725) > до k9_Росія (3.367) -> йде у Клас 2
#   - 'k7_Польща': до k3_ОАЕ (3.323) > до k9_Росія (2.819) -> йде у Клас 2
#   - 'k8_Португалія': до k3_ОАЕ (3.546) < до k9_Росія (4.433) -> йде у Клас 1
#   - 'k10_Саудівська Аравія': до k3_ОАЕ (1.595) < до k9_Росія (4.153) -> йде у Клас 1
#
# РЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ 1:
# Клас 1: ['k3', 'k1', 'k2', 'k4', 'k8', 'k10']
# Клас 2: ['k9', 'k5', 'k6', 'k7']
#
# Крок 2: Розглядаємо кластер розміром 6 об'єктів.
# Найбільша відстань Δd = 3.852 між 'k2_Норвегія' та 'k4_ПАР'.
# Вони стають центрами розбиття. Розподіляємо інші об'єкти:
#   - 'k3_ОАЕ': до k2_Норвегія (2.389) < до k4_ПАР (3.252) -> йде у Клас 1
#   - 'k1_Нова Зеландія': до k2_Норвегія (0.893) < до k4_ПАР (3.750) -> йде у Клас 1
#   - 'k8_Португалія': до k2_Норвегія (3.400) > до k4_ПАР (1.843) -> йде у Клас 2
#   - 'k10_Саудівська Аравія': до k2_Норвегія (3.464) > до k4_ПАР (2.332) -> йде у Клас 2
#
# РЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ 2:
# Клас 1: ['k2', 'k3', 'k1']
# Клас 2: ['k4', 'k8', 'k10']
#
# Крок 3: Розглядаємо кластер розміром 3 об'єктів.
# Найбільша відстань Δd = 3.376 між 'k8_Португалія' та 'k10_Саудівська Аравія'.
# Вони стають центрами розбиття. Розподіляємо інші об'єкти:
#   - 'k4_ПАР': до k8_Португалія (1.843) < до k10_Саудівська Аравія (2.332) -> йде у Клас 1
#
# РЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ 3:
# Клас 1: ['k8', 'k4']
# Клас 2: ['k10']
#
# Крок 4: Розглядаємо кластер розміром 4 об'єктів.
# Найбільша відстань Δd = 3.367 між 'k9_Росія' та 'k6_Північна Корея'.
# Вони стають центрами розбиття. Розподіляємо інші об'єкти:
#   - 'k5_Південна Корея': до k9_Росія (2.524) > до k6_Північна Корея (1.474) -> йде у Клас 2
#   - 'k7_Польща': до k9_Росія (2.819) > до k6_Північна Корея (0.776) -> йде у Клас 2
#
# РЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ 4:
# Клас 1: ['k9']
# Клас 2: ['k6', 'k5', 'k7']
#
# Крок 5: Розглядаємо кластер розміром 3 об'єктів.
# Найбільша відстань Δd = 2.389 між 'k2_Норвегія' та 'k3_ОАЕ'.
# Вони стають центрами розбиття. Розподіляємо інші об'єкти:
#   - 'k1_Нова Зеландія': до k2_Норвегія (0.893) < до k3_ОАЕ (2.260) -> йде у Клас 1
#
# РЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ 5:
# Клас 1: ['k2', 'k1']
# Клас 2: ['k3']
#
# Крок 6: Розглядаємо кластер розміром 2 об'єктів.
# Найбільша відстань Δd = 1.843 між 'k8_Португалія' та 'k4_ПАР'.
# Вони стають центрами розбиття. Розподіляємо інші об'єкти:
#
# РЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ 6:
# Клас 1: ['k8']
# Клас 2: ['k4']
#
# Крок 7: Розглядаємо кластер розміром 3 об'єктів.
# Найбільша відстань Δd = 1.474 між 'k6_Північна Корея' та 'k5_Південна Корея'.
# Вони стають центрами розбиття. Розподіляємо інші об'єкти:
#   - 'k7_Польща': до k6_Північна Корея (0.776) < до k5_Південна Корея (0.840) -> йде у Клас 1
#
# РЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ 7:
# Клас 1: ['k6', 'k7']
# Клас 2: ['k5']
#
# Крок 8: Розглядаємо кластер розміром 2 об'єктів.
# Найбільша відстань Δd = 0.893 між 'k2_Норвегія' та 'k1_Нова Зеландія'.
# Вони стають центрами розбиття. Розподіляємо інші об'єкти:
#
# РЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ 8:
# Клас 1: ['k2']
# Клас 2: ['k1']
#
# Крок 9: Розглядаємо кластер розміром 2 об'єктів.
# Найбільша відстань Δd = 0.776 між 'k6_Північна Корея' та 'k7_Польща'.
# Вони стають центрами розбиття. Розподіляємо інші об'єкти:
#
# РЕЗУЛЬТАТ РОЗБИТТЯ НА КРОЦІ 9:
# Клас 1: ['k6']
# Клас 2: ['k7']
